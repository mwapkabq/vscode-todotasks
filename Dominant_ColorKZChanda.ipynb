# %% [markdown]
# <a href="https://colab.research.google.com/github/mwapkabq/vscode-todotasks/blob/master/Dominant_ColorKZChanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mwapkabq/ML-Bootcamp.git
# Out:
# Cloning into 'ML-Bootcamp'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 530 (delta 86), reused 77 (delta 36), pack-reused 348
# Receiving objects: 100% (530/530), 13.17 MiB | 15.81 MiB/s, done.
# Resolving deltas: 100% (176/176), done.

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("/content/kabwepic.jpeg")

img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
img = cv2.resize(img,(280,282))

img.shape
# Out:
# (282, 280, 3)

# %%
plt.imshow(img)
plt.show()

# %%
X = img.reshape((-1,3))
X.shape
# Out:
# (78960, 3)

# %%
from sklearn.cluster import KMeans

# %%
k = 4
model = KMeans(n_clusters = k)
model.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
centroids = model.cluster_centers_

# %%
centroids
# Out:
# array([[ 89.14561545,  89.14561545,  89.14561545],
#        [252.45337802, 252.45337802, 252.45337802],
#        [ 30.67248638,  30.67248638,  30.67248638],
#        [150.65866578, 150.65866578, 150.65866578]])

# %%
import numpy as np

# %%
colors = np.array(centroids,dtype='uint8')

# %%
colors
# Out:
# array([[ 89,  89,  89],
#        [252, 252, 252],
#        [ 30,  30,  30],
#        [150, 150, 150]], dtype=uint8)

# %%
i = 1

for color in colors:
    plt.subplot(1,k,i)
    plt.axis("off")
    i = i + 1
    mat = np.zeros((100,100,3),dtype='uint8')
    mat[:,:,:] = color
    plt.imshow(mat)

plt.show()
